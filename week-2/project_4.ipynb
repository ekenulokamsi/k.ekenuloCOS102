# %%
# Program to 

experience = float(input("Enter years of experience: "))
age = float(input("Enter age of staff: "))

if experience > 25 and age >= 55:
   print("ATR = 5,600,000")

elif experience > 20 and age >= 45:
    print("ATR = 4,480,000")

elif experience > 10 and age >= 35:
     print("ATR = 1,500,000")

else:
    print("ATR = 550,000")

print("Stafff Annual Tax Revenue Calculator")
# Out:
# Enter years of experience:  5
# Enter age of staff:  27
# ATR = 550,000
# Stafff Annual Tax Revenue Calculator
