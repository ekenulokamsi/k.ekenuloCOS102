# %%
# Girls Data
girls_names = ["Evelyn","Jessica","Somto","Edith","Liza","Madonna","Waje","Tola","Aisha","Latifa"]
girls_age = [17,16,17,18,16,18,17,20,19,17]
girls_height = [5.5,6.0,5.4,5.9,5.5,5.6,6.1,6.0,5.7,5.5]
girls_scores = [80,85,70,60,76,66,87,95,50,49]

# Boys Data
boys_names = ["Chinedu", "Liam", "Wale", "Gbenga","Abiola","Kola","Kunle","George","Thomas","Wesley"]
boys_age = [19,16,18,17,20,19,16,18,17,19]
boys_height = [5.7,5.9,5.8,6.1,5.9,5.5,6.1,6.0,5.7,5.5]
boys_scores = [74,87,75,68,66,78,87,98,54,60]

# Print Girls Table
print("GIRLS")
print("Name | Age | Height | Score")

for i in range(len(girls_names)):
    print(girls_names[i], "|", girls_age[i], "|", girls_height[i], "|", girls_scores[i],)

print("\n")

# Print Boys Table
print("BOYS")
print("Name | Age | Height | Score")

for i in range(len(boys_names)):
    print(boys_names[i], "|", boys_age[i], "|", boys_height[i], "|", boys_scores[i])
# Out:
# GIRLS
# Name | Age | Height | Score
# Evelyn | 17 | 5.5 | 80
# Jessica | 16 | 6.0 | 85
# Somto | 17 | 5.4 | 70
# Edith | 18 | 5.9 | 60
# Liza | 16 | 5.5 | 76
# Madonna | 18 | 5.6 | 66
# Waje | 17 | 6.1 | 87
# Tola | 20 | 6.0 | 95
# Aisha | 19 | 5.7 | 50
# Latifa | 17 | 5.5 | 49
#
#
# BOYS
# Name | Age | Height | Score
# Chinedu | 19 | 5.7 | 74
# Liam | 16 | 5.9 | 87
# Wale | 18 | 5.8 | 75
# Gbenga | 17 | 6.1 | 68
# Abiola | 20 | 5.9 | 66
# Kola | 19 | 5.5 | 78
# Kunle | 16 | 6.1 | 87
# George | 18 | 6.0 | 98
# Thomas | 17 | 5.7 | 54
# Wesley | 19 | 5.5 | 60
