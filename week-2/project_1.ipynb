# %% [markdown]
# BEGIN
# Scan items
# Calculate total price
# Display total price
# Receive payment
#
# IF payment successful
# Print receipt
# Give items to customer
# ELSE
# Ask customer to pay again
# END IF
#
# END
