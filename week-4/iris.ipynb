# %%
# %pip install pandas numpy matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 1.26.4

# %%
import pandas as pd

# %%
data = pd.read_csv("/home/ekenulokamsi/k.ekenuloCOS102/week-4/iris.csv")
